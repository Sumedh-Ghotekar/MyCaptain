# %%
import csv

def write_into_csv(info_list):
    with open('student_info.csv','a',newline='') as csv_file:
        writer =csv.writer(csv_file)
        if csv_file.tell()==0:
            writer.writerow(["Name","Age","Contact Number","E-mail ID"])
        writer.writerow(info_list)
        
        
if __name__=='__main__':        
    condition = True
    student_num=1

    while(condition):
        student_info=input("Enter some Student information for the student#{} in the folowing formaT(Name Age Contact_number E-mail_ID):".format(student_num))

    
        print("Entered information: "+ student_info)
    
        student_info_list=student_info.split(' ')
        print("Entered split up information is :"+str(student_info_list))
        print("\nThe entered information is-\nName: {}\nAge: {}\nContact_number: {}\nEmail ID: {}".format(student_info_list[0],student_info_list[1],student_info_list[2],student_info_list[3],))
        choice_check=input("Is the entered information Correct?(yes/no):")
        if choice_check=='yes':
            write_into_csv(student_info_list)
            condition_check=input("Enter(yes/no) if you want to enter information for another student:")
            if condition_check=="yes":
                condition=True
                student_num = student_num +1
            elif condition_check=="no":
                condition=False
        if choice_check=='no':
            print("Please re-enter the values!")
# Out:
# Enter some Student information for the student#1 in the folowing formaT(Name Age Contact_number E-mail_ID):raj 13 372846 abc@dasd.com
# Entered information: raj 13 372846 abc@dasd.com
# Entered split up information is :['raj', '13', '372846', 'abc@dasd.com']
#
# The entered information is-
# Name: raj
# Age: 13
# Contact_number: 372846
# Email ID: abc@dasd.com
# Is the entered information Correct?(yes/no):yes
# Enter(yes/no) if you want to enter information for another student:yes
# Enter some Student information for the student#2 in the folowing formaT(Name Age Contact_number E-mail_ID):rajiv 14 37284655 arbc@dasd.com
# Entered information: rajiv 14 37284655 arbc@dasd.com
# Entered split up information is :['rajiv', '14', '37284655', 'arbc@dasd.com']
#
# The entered information is-
# Name: rajiv
# Age: 14
# Contact_number: 37284655
# Email ID: arbc@dasd.com
# Is the entered information Correct?(yes/no):yes
# Enter(yes/no) if you want to enter information for another student:yes
# ...
